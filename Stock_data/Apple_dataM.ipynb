# %%
import quandl
from datetime import datetime
import pandas as pd

# %%
# pull data for microsoft, apple, google, amazon , bitcoin

quandl.ApiConfig.api_key = "V2vzspYSYL8eenGuq8uF "
url = 'https://www.quandl.com/api/v3/databases/EOD/metadata?api_key=V2vzspYSYL8eenGuq8uF'
# https://www.quandl.com/api/v3/datasets/WIKI/$%7Bstock%7D.json?start_date=2016-10-01&end_date=2017-10-01&api_key=${apiKey}`;

# %%
#Database for AAPL
mydata = pd.DataFrame(quandl.get("EOD/AAPL",collapse="monthly"))
mydata.head()
# Out:
#              Open   High    Low  Close    Volume  Dividend  Split  Adj_Open  \
# Date
# 1980-12-31  34.25  34.25  34.13  34.13  159600.0       0.0    1.0  0.496077
# 1981-01-31  28.50  28.50  28.25  28.25  206200.0       0.0    1.0  0.412794
# 1981-02-28  26.50  26.75  26.50  26.50   65900.0       0.0    1.0  0.383826
# 1981-03-31  24.75  24.75  24.50  24.50   71400.0       0.0    1.0  0.358479
# 1981-04-30  28.38  28.62  28.38  28.38   56300.0       0.0    1.0  0.411056
#
#             Adj_High   Adj_Low  Adj_Close  Adj_Volume
# Date
# 1980-12-31  0.496077  0.494339   0.494339   8937600.0
# 1981-01-31  0.412794  0.409173   0.409173  11547200.0
# 1981-02-28  0.387447  0.383826   0.383826   3690400.0
# 1981-03-31  0.358479  0.354858   0.354858   3998400.0
# 1981-04-30  0.414532  0.411056   0.411056   3152800.0

# %%
Appledata = mydata[["Open","High","Low","Close","Volume","Split"]]
# Appledata = pd.DataFrame(Appledata)

# %%
Appledata.reset_index(inplace = True)

Appledata.head()
# Appledata.dtypes
# Out:
#         Date   Open   High    Low  Close    Volume  Split
# 0 1980-12-31  34.25  34.25  34.13  34.13  159600.0    1.0
# 1 1981-01-31  28.50  28.50  28.25  28.25  206200.0    1.0
# 2 1981-02-28  26.50  26.75  26.50  26.50   65900.0    1.0
# 3 1981-03-31  24.75  24.75  24.50  24.50   71400.0    1.0
# 4 1981-04-30  28.38  28.62  28.38  28.38   56300.0    1.0

# %%
gg = []
ggN = []
for hh in Appledata["Date"]:
    
    gg.append(f"{hh.year}-{hh.month}-{hh.day}")
    ggN.append(f"{hh.year}-{hh.month}-{hh.day}")
#     print(hh.month)
# gg.remove(-1)
print(len(ggN))
del gg[-1]
len(gg)
# Out:
# 454
# 453

# %%
Volume = []
for Vo in Appledata["Volume"]:
    Volume.append(Vo)
len(Volume)    
Close = []
for Co in Appledata["Close"]:
    Close.append(Co)
len(Close)
# Out:
# 454

# %%
year = 1980

x = 0
changes = []
while x < (len(Appledata)-1):
    openV = Appledata["Open"][x]

    closeV = Appledata["Close"][x+1]
    changes.append(round((closeV-openV)/openV*100, 2))

    x += 1
print(changes)
# Out:
# [-17.52, -7.02, -7.55, 14.67, 16.74, -21.52, -4.32, -19.48, -24.24, 31.15, -6.85, 18.03, -7.91, -10.45, -7.51, -12.62, -5.08, -8.93, 5.88, 33.33, 1.39, 38.11, 26.91, 3.46, 36.23, 11.27, -9.63, 14.12, 15.5, -17.5, -28.99, 9.56, -30.18, -0.53, -3.5, 17.49, 1.52, 6.06, -2.94, 23.69, -2.52, -8.62, -3.3, 3.92, -6.96, -3.42, -1.0, 14.78, -0.41, -17.14, -11.94, -2.83, -18.26, 2.16, -13.55, -7.69, 5.0, 17.25, 5.89, 10.0, 3.91, 8.7, 10.27, 7.08, 18.4, -3.03, -12.9, 21.31, -10.98, 5.32, 16.79, 0.0, 35.37, 29.63, -6.68, 27.31, 1.28, -49.53, 1.85, 30.91, 8.13, -28.79, -17.5, 24.44, -2.35, 3.61, -4.19, 3.14, 0.61, 15.62, -4.04, -7.79, 5.49, -12.2, -2.89, 9.52, -6.79, -2.68, -2.38, 11.43, 21.66, -13.16, -1.85, 13.38, 0.0, 2.76, -3.28, -19.43, -2.16, -1.45, 20.15, -1.55, 5.1, 7.83, -2.33, -12.94, -19.44, 7.89, 20.49, 18.62, 29.07, 3.15, 16.74, -20.58, -18.61, -12.63, 9.47, 13.98, -6.6, 4.57, 0.0, 11.64, 12.84, 5.47, -14.96, 3.23, 4.37, -19.67, 0.0, -2.65, 0.29, 16.67, 7.48, 6.22, 1.28, -12.03, -5.07, -2.38, 11.59, -30.7, -28.39, -3.64, -11.81, 28.12, 1.61, -7.87, 10.08, 8.96, -8.28, -7.69, -2.5, -10.17, 28.34, 13.56, -6.42, 26.55, -11.31, 1.62, 2.54, -2.47, -8.44, 8.88, 9.37, 10.23, -4.76, -5.49, -14.13, -4.45, 8.17, -18.03, -13.69, -0.9, -10.69, 0.49, 5.03, -18.03, 5.41, 14.12, -10.34, 3.98, 3.74, -14.82, -22.23, -2.23, 8.18, -8.7, -2.24, -13.64, 18.64, 25.22, -0.55, -22.59, 2.19, -25.48, 39.45, 29.0, 17.98, -0.26, -2.74, 4.33, 21.0, -14.85, 9.73, -4.18, -13.23, 18.46, 1.7, -15.49, -1.53, 26.44, 0.14, 6.93, 21.89, 19.72, 1.15, 34.52, 24.18, 4.78, 2.78, 13.49, 19.59, -2.65, -33.92, -39.7, -3.79, 23.96, -56.33, -30.61, -16.46, -10.84, 47.17, -15.12, 13.94, 13.04, -25.28, 17.42, -20.58, -3.74, -12.52, 11.78, 20.14, 6.99, 9.82, -10.18, 6.86, 2.41, -2.47, -26.44, -10.76, -4.22, -1.56, 11.6, -3.06, -9.25, 2.57, 5.78, -4.85, -0.84, 28.86, 5.19, 12.85, 9.02, -6.67, 8.53, -10.26, 2.84, 5.67, 5.19, 17.77, -7.47, 5.05, 15.88, -0.52, 5.51, 13.74, 34.36, 29.04, -6.31, 18.51, -39.85, -6.74, -15.05, 9.98, -9.47, 16.5, 7.64, 14.58, 10.05, 22.86, 5.06, 6.49, -9.28, -12.4, 11.31, -13.69, -7.26, 18.01, 1.53, 14.42, 5.15, 12.54, -8.0, 2.12, -0.29, 11.94, 5.85, 21.08, 1.64, 8.03, -3.14, 10.02, 23.79, -2.88, 5.73, -32.15, -3.42, 10.6, 21.41, 7.09, -10.7, -6.52, 7.5, -34.29, -0.61, -13.72, -9.87, 4.84, -3.57, 19.58, 19.33, 7.6, 5.2, 14.6, 3.2, 10.22, 1.27, 1.97, 4.78, -9.88, 1.76, 16.12, 10.87, -4.62, -3.03, 0.21, -5.0, 17.32, 4.15, 2.27, 2.88, 5.07, 5.18, -0.78, 1.09, 0.3, -1.59, 16.67, -0.72, -2.37, 4.56, -5.02, 6.22, 13.13, 19.06, 10.71, -4.07, -3.36, 0.56, 5.67, 10.28, -0.02, -12.29, -1.61, -9.31, -10.78, -3.41, -0.31, -1.57, 3.36, -12.37, 15.63, 7.08, -3.1, 9.52, 5.92, 2.1, -9.67, 6.27, 1.45, 9.43, 6.81, -85.43, 3.8, 5.5, -2.05, 7.13, 10.11, -7.45, 3.85, 8.5, -4.28, -0.75, 2.18, -4.42, -3.4, -8.03, -1.94, 8.47, -2.22, -10.79, -9.04, 2.0, 12.52, -14.56, 6.25, -4.02, 10.35, 1.83, 6.99, 0.96, -2.75, 3.82, 4.03, 13.07, 4.8, -0.05, 6.02, -6.46, 2.96, 9.41, -5.82, 10.33, 2.35, -0.7, -1.81, 6.74, -6.4, -1.52, 15.26, -1.13, 2.15, 19.62, -3.81]

# %%
months = ["January","Febuary","March","April","May","June","July","August","Septemeber","October","November","December"]
year = 1981
labels = []
while year < 2018:
    for month in months:
        labels.append(str(month) + " " + str(year))
    year += 1    
labels.append("January 2018")
labels.append("Febuary 2018")
labels.append("March 2018")
labels.append("April 2018")
labels.append("May 2018")
labels.append("June 2018")
labels.append("July 2018")
labels.append("August 2018")
labels = ["Dec1980"] + labels




labels
# Out:
# ['Dec1980',
#  'January 1981',
#  'Febuary 1981',
#  'March 1981',
#  'April 1981',
#  'May 1981',
#  'June 1981',
#  'July 1981',
#  'August 1981',
#  'Septemeber 1981',
#  'October 1981',
#  'November 1981',
#  'December 1981',
#  'January 1982',
#  'Febuary 1982',
#  'March 1982',
#  'April 1982',
#  'May 1982',
#  'June 1982',
#  'July 1982',
#  'August 1982',
#  'Septemeber 1982',
#  'October 1982',
#  'November 1982',
#  'December 1982',
#  'January 1983',
#  'Febuary 1983',
#  'March 1983',
#  'April 1983',
#  'May 1983',
#  'June 1983',
#  'July 1983',
#  'August 1983',
#  'Septemeber 1983',
#  'October 1983',
#  'November 1983',
#  'December 1983',
#  'January 1984',
#  'Febuary 1984',
#  'March 1984',
#  'April 1984',
#  'May 1984',
#  'June 1984',
#  'July 1984',
#  'August 1984',
#  'Septemeber 1984',
#  'October 1984',
#  'November 1984',
#  'December 1984',
#  'January 1985',
#  'Febuary 1985',
#  'March 1985',
#  'April 1985',
#  'May 1985',
#  'June 1985',
#  'July 1985',
#  'August 1985',
#  'Septemeber 1985',
#  'October 1985',
#  'November 1985',
#  'December 1985',
#  'January 1986',
#  'Febuary 1986',
#  'March 1986',
#  'April 1986',
#  'May 1986',
#  'June 1986',
#  'July 1986',
#  'August 1986',
#  'Septemeber 1986',
#  'October 1986',
#  'November 1986',
#  'December 1986',
#  'January 1987',
#  'Febuary 1987',
#  'March 1987',
#  'April 1987',
#  'May 1987',
#  'June 1987',
#  'July 1987',
#  'August 1987',
#  'Septemeber 1987',
#  'October 1987',
#  'November 1987',
#  'December 1987',
#  'January 1988',
#  'Febuary 1988',
#  'March 1988',
#  'April 1988',
#  'May 1988',
#  'June 1988',
#  'July 1988',
#  'August 1988',
#  'Septemeber 1988',
#  'October 1988',
#  'November 1988',
#  'December 1988',
#  'January 1989',
#  'Febuary 1989',
#  'March 1989',
#  'April 1989',
#  'May 1989',
#  'June 1989',
#  'July 1989',
#  'August 1989',
#  'Septemeber 1989',
#  'October 1989',
#  'November 1989',
#  'December 1989',
#  'January 1990',
#  'Febuary 1990',
#  'March 1990',
#  'April 1990',
#  'May 1990',
#  'June 1990',
#  'July 1990',
#  'August 1990',
#  'Septemeber 1990',
#  'October 1990',
#  'November 1990',
#  'December 1990',
#  'January 1991',
#  'Febuary 1991',
#  'March 1991',
#  'April 1991',
#  'May 1991',
#  'June 1991',
#  'July 1991',
#  'August 1991',
#  'Septemeber 1991',
#  'October 1991',
#  'November 1991',
#  'December 1991',
#  'January 1992',
#  'Febuary 1992',
#  'March 1992',
#  'April 1992',
#  'May 1992',
#  'June 1992',
#  'July 1992',
#  'August 1992',
#  'Septemeber 1992',
#  'October 1992',
#  'November 1992',
#  'December 1992',
#  'January 1993',
#  'Febuary 1993',
#  'March 1993',
#  'April 1993',
#  'May 1993',
#  'June 1993',
#  'July 1993',
#  'August 1993',
#  'Septemeber 1993',
#  'October 1993',
#  'November 1993',
#  'December 1993',
#  'January 1994',
#  'Febuary 1994',
#  'March 1994',
#  'April 1994',
#  'May 1994',
#  'June 1994',
#  'July 1994',
#  'August 1994',
#  'Septemeber 1994',
#  'October 1994',
#  'November 1994',
#  'December 1994',
#  'January 1995',
#  'Febuary 1995',
#  'March 1995',
#  'April 1995',
#  'May 1995',
#  'June 1995',
#  'July 1995',
#  'August 1995',
#  'Septemeber 1995',
#  'October 1995',
#  'November 1995',
#  'December 1995',
#  'January 1996',
#  'Febuary 1996',
#  'March 1996',
#  'April 1996',
#  'May 1996',
#  'June 1996',
#  'July 1996',
#  'August 1996',
#  'Septemeber 1996',
#  'October 1996',
#  'November 1996',
#  'December 1996',
#  'January 1997',
#  'Febuary 1997',
#  'March 1997',
#  'April 1997',
#  'May 1997',
#  'June 1997',
#  'July 1997',
#  'August 1997',
#  'Septemeber 1997',
#  'October 1997',
#  'November 1997',
#  'December 1997',
#  'January 1998',
#  'Febuary 1998',
#  'March 1998',
#  'April 1998',
#  'May 1998',
#  'June 1998',
#  'July 1998',
#  'August 1998',
#  'Septemeber 1998',
#  'October 1998',
#  'November 1998',
#  'December 1998',
#  'January 1999',
#  'Febuary 1999',
#  'March 1999',
#  'April 1999',
#  'May 1999',
#  'June 1999',
#  'July 1999',
#  'August 1999',
#  'Septemeber 1999',
#  'October 1999',
#  'November 1999',
#  'December 1999',
#  'January 2000',
#  'Febuary 2000',
#  'March 2000',
#  'April 2000',
#  'May 2000',
#  'June 2000',
#  'July 2000',
#  'August 2000',
#  'Septemeber 2000',
#  'October 2000',
#  'November 2000',
#  'December 2000',
#  'January 2001',
#  'Febuary 2001',
#  'March 2001',
#  'April 2001',
#  'May 2001',
#  'June 2001',
#  'July 2001',
#  'August 2001',
#  'Septemeber 2001',
#  'October 2001',
#  'November 2001',
#  'December 2001',
#  'January 2002',
#  'Febuary 2002',
#  'March 2002',
#  'April 2002',
#  'May 2002',
#  'June 2002',
#  'July 2002',
#  'August 2002',
#  'Septemeber 2002',
#  'October 2002',
#  'November 2002',
#  'December 2002',
#  'January 2003',
#  'Febuary 2003',
#  'March 2003',
#  'April 2003',
#  'May 2003',
#  'June 2003',
#  'July 2003',
#  'August 2003',
#  'Septemeber 2003',
#  'October 2003',
#  'November 2003',
#  'December 2003',
#  'January 2004',
#  'Febuary 2004',
#  'March 2004',
#  'April 2004',
#  'May 2004',
#  'June 2004',
#  'July 2004',
#  'August 2004',
#  'Septemeber 2004',
#  'October 2004',
#  'November 2004',
#  'December 2004',
#  'January 2005',
#  'Febuary 2005',
#  'March 2005',
#  'April 2005',
#  'May 2005',
#  'June 2005',
#  'July 2005',
#  'August 2005',
#  'Septemeber 2005',
#  'October 2005',
#  'November 2005',
#  'December 2005',
#  'January 2006',
#  'Febuary 2006',
#  'March 2006',
#  'April 2006',
#  'May 2006',
#  'June 2006',
#  'July 2006',
#  'August 2006',
#  'Septemeber 2006',
#  'October 2006',
#  'November 2006',
#  'December 2006',
#  'January 2007',
#  'Febuary 2007',
#  'March 2007',
#  'April 2007',
#  'May 2007',
#  'June 2007',
#  'July 2007',
#  'August 2007',
#  'Septemeber 2007',
#  'October 2007',
#  'November 2007',
#  'December 2007',
#  'January 2008',
#  'Febuary 2008',
#  'March 2008',
#  'April 2008',
#  'May 2008',
#  'June 2008',
#  'July 2008',
#  'August 2008',
#  'Septemeber 2008',
#  'October 2008',
#  'November 2008',
#  'December 2008',
#  'January 2009',
#  'Febuary 2009',
#  'March 2009',
#  'April 2009',
#  'May 2009',
#  'June 2009',
#  'July 2009',
#  'August 2009',
#  'Septemeber 2009',
#  'October 2009',
#  'November 2009',
#  'December 2009',
#  'January 2010',
#  'Febuary 2010',
#  'March 2010',
#  'April 2010',
#  'May 2010',
#  'June 2010',
#  'July 2010',
#  'August 2010',
#  'Septemeber 2010',
#  'October 2010',
#  'November 2010',
#  'December 2010',
#  'January 2011',
#  'Febuary 2011',
#  'March 2011',
#  'April 2011',
#  'May 2011',
#  'June 2011',
#  'July 2011',
#  'August 2011',
#  'Septemeber 2011',
#  'October 2011',
#  'November 2011',
#  'December 2011',
#  'January 2012',
#  'Febuary 2012',
#  'March 2012',
#  'April 2012',
#  'May 2012',
#  'June 2012',
#  'July 2012',
#  'August 2012',
#  'Septemeber 2012',
#  'October 2012',
#  'November 2012',
#  'December 2012',
#  'January 2013',
#  'Febuary 2013',
#  'March 2013',
#  'April 2013',
#  'May 2013',
#  'June 2013',
#  'July 2013',
#  'August 2013',
#  'Septemeber 2013',
#  'October 2013',
#  'November 2013',
#  'December 2013',
#  'January 2014',
#  'Febuary 2014',
#  'March 2014',
#  'April 2014',
#  'May 2014',
#  'June 2014',
#  'July 2014',
#  'August 2014',
#  'Septemeber 2014',
#  'October 2014',
#  'November 2014',
#  'December 2014',
#  'January 2015',
#  'Febuary 2015',
#  'March 2015',
#  'April 2015',
#  'May 2015',
#  'June 2015',
#  'July 2015',
#  'August 2015',
#  'Septemeber 2015',
#  'October 2015',
#  'November 2015',
#  'December 2015',
#  'January 2016',
#  'Febuary 2016',
#  'March 2016',
#  'April 2016',
#  'May 2016',
#  'June 2016',
#  'July 2016',
#  'August 2016',
#  'Septemeber 2016',
#  'October 2016',
#  'November 2016',
#  'December 2016',
#  'January 2017',
#  'Febuary 2017',
#  'March 2017',
#  'April 2017',
#  'May 2017',
#  'June 2017',
#  'July 2017',
#  'August 2017',
#  'Septemeber 2017',
#  'October 2017',
#  'November 2017',
#  'December 2017',
#  'January 2018',
#  'Febuary 2018',
#  'March 2018',
#  'April 2018',
#  'May 2018',
#  'June 2018',
#  'July 2018',
#  'August 2018']

# %%
Appl_json = {
    "numbers": changes, 
    "labels": labels,
    "Dates": gg,
    "Dates_Normal": ggN,
    "Volume": Volume, 
    "Close": Close
}

# %%
import pymongo

# Create connection variable
conn = 'mongodb://localhost:27017'

# Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)

# Connect to a database. Will create one if not already available.
db = client.Apple_y_y

# Drops collection if available to remove duplicates
db.apple_y_o_y.drop()

# Creates a collection in the database and insert document
db.apple_y_o_y.insert_one(
    Appl_json
)

# %%
len(labels)
# Out:
# 453
